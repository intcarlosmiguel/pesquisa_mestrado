# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
a = np.loadtxt("./C/output/infect/0.001.txt",delimiter= ' ').T
b = np.loadtxt("./C/output/infect/0.341.txt",delimiter= ' ').T

# %%
a[-1][-1]/2029
# Out:
# 0.005914243469689502

# %%
lista = os.listdir('./C/output/infect/')
infect = []
for i in lista:
    a = np.loadtxt('./C/output/infect/'+i,delimiter= ' ').T
    infect.append(a[-1][-1])
infect = np.array(infect)

# %%
lista = np.array([float(i[:-4]) for i in lista])

# %%
infect
# Out:
# array([ 3.,  5., 13., ...,  7.,  6.,  4.])

# %%
plt.scatter(lista,infect)
plt.show()

# %%
x,y = np.unique(infect,return_counts=True)

# %%
lista[infect == x[y == np.max(y)][0]]
# Out:
# array([0.079, 0.168, 0.397, 0.411, 0.834, 0.618, 0.543, 0.04 , 0.044,
#        0.602, 0.794, 0.757, 0.805, 0.915, 0.829, 0.581, 0.883, 0.663,
#        0.644, 0.658, 0.799, 0.919, 0.242, 0.346, 0.038, 0.78 , 0.137,
#        0.861, 0.608, 0.816, 0.924, 0.094, 0.46 , 0.836, 0.177, 0.668,
#        0.498, 0.495, 0.504, 0.211, 0.336, 0.988, 0.825, 0.586, 0.085,
#        0.391, 0.104, 0.87 , 0.755, 0.499, 0.309, 0.026, 0.196, 0.936,
#        0.544, 0.422, 0.693, 0.13 , 0.492, 0.771, 0.127, 0.814, 0.564,
#        0.022, 0.048, 0.929, 0.296, 0.784, 0.912, 0.648, 0.241, 0.166,
#        0.698, 0.952, 0.888, 0.186, 0.042, 0.955, 0.824, 0.068, 0.041,
#        0.752, 0.809, 0.402, 0.773, 0.801, 0.785, 0.984, 0.653, 0.758,
#        0.972, 0.977, 0.429, 0.413, 0.894, 0.702, 0.764, 0.84 , 0.891,
#        0.926, 0.367, 0.227, 0.565, 0.652, 0.128, 0.133, 0.121, 0.24 ,
#        0.031, 0.214, 0.828, 0.717, 0.776, 0.534, 0.701, 0.002, 0.018,
#        0.165, 0.978])

# %%
lista
# Out:
# array([0.685, 0.731, 0.552, ..., 0.697, 0.914, 0.44 ])

# %%
s = []
for i in range(len(x) -1):
    s.append('[{:.2f},{:.2f}]'.format(x[i],x[i+1]))

# %%
plt.bar(x,y)
plt.show()

# %%
plt.plot(np.cumsum(a[0]),a[1]/2029,label = 'Suscetível')
plt.plot(np.cumsum(a[0]),a[2]/2029,label = 'Expostos')
plt.plot(np.cumsum(a[0]),a[-2]/2029,label = 'Recuperados')
plt.plot(np.cumsum(a[0]),a[-3]/2029,label = 'Hospitalizados')
plt.plot(np.cumsum(a[0]),a[-1]/2029,label = 'Mortos')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(np.cumsum(a[0]),a[2]/2029,label = 'Expostos')
plt.plot(np.cumsum(b[0]),b[2]/2029,label = 'Expostos')
plt.legend()
plt.grid()
plt.show()

# %%
a[-1][-1]
# Out:
# 2.0

# %%
plt.plot(np.cumsum(a[0]),a[2]/2027,label = 'Expostos')
plt.plot(np.cumsum(a[0]),a[3]/2027,label = 'Assintomático')
plt.plot(np.cumsum(a[0]),a[4]/2027,label = 'Sintomático')
plt.legend()
plt.grid()
plt.show()
