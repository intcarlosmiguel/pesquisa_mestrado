# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
dir = [i for i in os.listdir('./C/output/infect/') if('0.' in i)]

# %%
dir
# Out:
# ['infect_1_0.10.txt',
#  'infect_1_0.00.txt',
#  'infect_1_0.90.txt',
#  'infect_1_0.50.txt']

# %%
vac = []
for i in dir:
    x = np.loadtxt(f'./C/output/infect/{i}')
    x = np.array([i for i in x if(sum(np.isnan(i)) == 0)]).T
    vac.append(np.vstack((np.arange(0,x.shape[1]/2,0.5),x)))

# %%
for infect,file in zip(vac,dir):
    #plt.plot(infect[0],infect[1]/2029,label = f'Suscetíveis {file[9:-4]}')
    plt.plot(infect[0],infect[2]/2029,label = f'Expostos {file[9:-4]}')
plt.legend()
plt.grid()
plt.ylim(0.01,0.1)
plt.xlim(50,300)
plt.show()

# %%
for infect,file in zip(vac,dir):
    #plt.plot(infect[0],infect[1]/2029,label = f'Suscetíveis {file[9:-4]}')
    plt.plot(infect[0],infect[-1]/2029,label = f'Mortos {file[9:-4]}')
plt.legend()
plt.grid()
plt.show()

# %%
for infect,file in zip(vac,dir):
    #plt.plot(infect[0],infect[1]/2029,label = f'Suscetíveis {file[9:-4]}')
    plt.plot(infect[0],infect[-3]/2029,label = f'Hospitalizados {file[9:-4]}')
plt.legend()
plt.grid()
#plt.ylim(0,0.1)
#plt.xlim(50,300)
plt.show()

# %%
plt.plot(infect[0],infect[1]/2029,label = 'Suscetíveis')
plt.plot(infect[0],infect[2]/2029,label = 'Expostos')
plt.plot(infect[0],infect[-2]/2029,label = 'Recuperados')
#plt.plot(hist[0],hist[-3]/2029)
#plt.plot(hist[0],hist[-1]/2029)
plt.legend()
plt.grid()
plt.xlim(0,80)
plt.show()

# %%
#plt.plot(infect[0],infect[1]/2029,label = 'Suscetíveis')
#plt.plot(infect[0],infect[2]/2029,label = 'Expostos')
#plt.plot(infect[0],infect[-2]/2029,label = 'Recuperados')
plt.plot(infect[0],infect[-3]/2029,label = 'Hospitalizados', c = 'navy')
plt.plot(infect[0],infect[-1]/2029,label = 'Mortos', c = 'teal')
plt.legend()
plt.grid()
#plt.xlim(0,80)
plt.show()

# %%
vac = np.loadtxt('./C/output/infect/infect_1_0.900000.txt').T
vac = np.vstack((np.arange(0,365*3,0.5),vac))
infect = np.loadtxt('./C/output/infect/infect_1_0.000000.txt').T
infect = np.vstack((np.arange(0,365*3,0.5),infect))

# %%
plt.plot(vac[0],vac[1]/2029,label = 'Suscetíveis')
plt.plot(vac[0],vac[2]/2029,label = 'Expostos')
plt.plot(vac[0],vac[-2]/2029,label = 'Recuperados')
#plt.plot(hist[0],hist[-3]/2029)
#plt.plot(hist[0],hist[-1]/2029)
plt.legend()
plt.grid()
plt.xlim(0,80)
plt.show()

# %%
plt.plot(vac[0],vac[-3]/2029,label = 'Hospitalizados', c = 'navy')
plt.plot(vac[0],vac[-1]/2029,label = 'Mortos', c = 'teal')
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(vac[0],vac[2]/2029,label = 'Expostos com Vacina')
plt.plot(infect[0],infect[2]/2029,label = 'Expostos')
plt.legend()
plt.grid()
plt.xlim(0,200)
plt.show()

# %%
x = np.loadtxt('./C/output/infect/infect_vacinado.txt').T
y = np.loadtxt('./C/output/infect/infect_vacinado_grau.txt').T
z = np.loadtxt('./C/output/infect/infect_vacinado_ano.txt').T

# %%
plt.scatter(x[0],x[1],label = 'Vacinação Aleatória',s = 5,marker ='D')
plt.scatter(y[0],y[1],label = 'Vacinação por Grau',s = 5,marker ='D')
plt.scatter(z[0],z[1],label = 'Vacinação por Idade',s = 5,marker ='D')
#plt.scatter(x[0],x[1])
plt.ylabel('Número de Hospitalizados')
plt.xlabel('Fração da Vacinados')
plt.grid()
plt.legend()
plt.show()

# %%
plt.scatter(x[0],x[2],label = 'Vacinação Aleatória')
plt.scatter(y[0],y[2],label = 'Vacinação por Grau')
plt.scatter(z[0],z[2],label = 'Vacinação por Idade')
#plt.scatter(x[0],x[1])
plt.ylabel('Número de Mortos')
plt.grid()
plt.xlabel('Fração da Vacinados')
plt.legend()
plt.show()

# %%
dir = [i for i in os.listdir('./C/output/infect/') if('0.' not in i)]

# %%
shape = np.loadtxt('./C/output/infect/'+'infect_shape_aleatorio.txt').T

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import os
"""
x = np.loadtxt('./C/output/infect/infect_vacinado.txt').T
plt.scatter(x[0],x[2])
#plt.scatter(x[0],x[1])
plt.ylabel('Número de Hospitalizados')
plt.xlabel('Fração da Vacinados')
plt.show()
"""
dir = [i for i in os.listdir('./C/output/infect/') if('0.' not in i)]
shape = np.loadtxt('./C/output/infect/'+'infect_shape_aleatorio.txt').T
fig = plt.figure(figsize=(8,8),dpi = 100)
ax = fig.add_subplot(111, projection='3d')

# Criação do scatter plot em 3D
ax.scatter(shape[0], shape[1], shape[2], marker='o',s=10,c = 'orangered')

# Definição dos rótulos dos eixos
ax.set_xlabel('Fração de Vacinados')
ax.set_ylabel('Eficácia da Vacina')
ax.set_zlabel('Número de Hospitalizados')
ax.set_box_aspect([1, 1, 1])
# Exibição do gráfico
plt.savefig('./img/infect/shape_hospitalizados.png')
plt.show()

# %%
x
# Out:
# array([[0.0000e+00, 5.0000e-03, 0.0000e+00, ..., 3.1000e-01, 3.2000e-01,
#         3.3000e-01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 7.1000e-01, 7.1000e-01,
#         7.1000e-01],
#        [6.1886e+02, 6.1240e+02, 6.3496e+02, ..., 5.5455e+02, 5.6221e+02,
#         5.4342e+02],
#        [7.2810e+01, 7.1330e+01, 7.4090e+01, ..., 6.4160e+01, 6.4430e+01,
#         6.3050e+01]])

# %%
fig = plt.figure(figsize=(8,8),dpi = 100)
ax = fig.add_subplot(111, projection='3d')

# Criação do scatter plot em 3D
ax.scatter(shape[0], shape[1], shape[2], marker='o',s=10,c = 'orangered')

# Definição dos rótulos dos eixos
ax.set_xlabel('Fração de Vacinados')
ax.set_ylabel('Eficácia da Vacina')
ax.set_zlabel('Número de Hospitalizados')
ax.set_box_aspect([1, 1, 1])
# Exibição do gráfico
plt.savefig('./img/infect/shape_hospitalizados.png')
plt.show()

# %%
fig = plt.figure(figsize=(8,8),dpi = 100)
ax = fig.add_subplot(111, projection='3d')

# Criação do scatter plot em 3D
ax.scatter(shape[0], shape[1], shape[3], marker='o',s=10,c = 'teal')

# Definição dos rótulos dos eixos
ax.set_xlabel('Fração de Vacinados')
ax.set_ylabel('Eficácia da Vacina')
ax.set_zlabel('Número de Mortos')
ax.set_box_aspect([1, 1, 1])
# Exibição do gráfico
plt.savefig('./img/infect/shape_mortos.png')
plt.show()
